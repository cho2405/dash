# %%
import pandas as pd
df = pd.read_csv('거래내용_7월.csv', encoding='utf-8').drop_duplicates().to_csv('거래내용_7월.csv',encoding='utf-8-sig', index=False)

# %%
pd.read_csv('거래내용_7월.csv', encoding='utf-8')
# Out:
#         지역코드      법정동         거래일                    아파트       지번      전용면적  \
# 0      11110      견지동  2021-07-20                대성스카이렉스      110  137.5500
# 1      11110      교북동  2021-07-03             경희궁자이(4단지)      126   37.2635
# 2      11110      교북동  2021-07-10             경희궁자이(4단지)      126   45.8790
# 3      11110      구기동  2021-07-03                   마운틴뷰    125-5   66.1300
# 4      11110      내수동  2021-07-19              경희궁의아침3단지       72  150.4800
# 5      11110      무악동  2021-07-08                인왕산아이파크       60   84.8580
# 6      11110      무악동  2021-07-10                     현대       82   84.9200
# 7      11110      무악동  2021-07-14               경희궁 롯데캐슬       89   59.6737
# 8      11110      부암동  2021-07-14                 부암스카이뷰    218-1   76.6500
# 9      11110      사직동  2021-07-15       광화문풍림스페이스본(106동)      9-1  144.5200
# 10     11110      사직동  2021-07-19  광화문풍림스페이스본(101동~105동)        9  147.3100
# ...

# %%
import json # import json module

# with statement
with open('TL_SCCO_SIG.json') as json_file:
    json_data = json.load(json_file)
